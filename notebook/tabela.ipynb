# %%
pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabula import read_pdf

# %%
cooperativas = read_pdf('C://fontes_dados//202103 - Quadro 03 - Quantitativo de cooperativas de crédito por tipo.pdf',pages='all')
# Out:
# Got stderr: out 28, 2021 10:41:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# ADVERTÊNCIA: No Unicode mapping for .notdef (26) in font Arial

# %%
lista_cooperativas = read_pdf('C://fontes_dados//cooperativas_tipo.pdf', pages='all')
# Out:
# Got stderr: out 28, 2021 10:54:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# ADVERTÊNCIA: No Unicode mapping for .notdef (26) in font Arial

# %%
df_cooperativas = lista_cooperativas[0]

# %%
df_cooperativas
# Out:
#                                 Classe de Cooperativa  Dez/16  Dez/17  Dez/18  \
# 0                                        Confederação     2.0     2.0     2.0
# 1                                             Central    35.0    35.0    35.0
# 2   Singular - Segmentação por Categoria e Critéri...     NaN     NaN     NaN
# 3                                Capital e Empréstimo   194.0   192.0   188.0
# 4                              Atividade Profissional     5.0     8.0     9.0
# 5                            Empregados ou Servidores   185.0   180.0   175.0
# 6          Natureza Associativa ou Cadeia de Negócios     NaN     NaN     NaN
# 7                                      Produtor Rural     4.0     4.0     4.0
# 8                                            Clássica   809.0   756.0   712.0
# 9                              Atividade Profissional    86.0    75.0    69.0
# 10                         Crédito Mútuo - Empregados     NaN     NaN     NaN
# ...

# %%
import tabula
import pandas as pd
df_cooperativas = pd.DataFrame()
tabula.convert_into(lista_cooperativas, df_cooperativas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e0541e26d0d2> in <module>
#       2 import pandas as pd
#       3 df_cooperativas = pd.DataFrame()
# ----> 4 tabula.convert_into(lista_cooperativas, df_cooperativas)
#
# ~\Anaconda3\lib\site-packages\tabula\io.py in convert_into(input_path, output_path, output_format, java_options, **kwargs)
#     542
#     543     if output_path is None or len(output_path) == 0:
# --> 544         raise ValueError("'output_path' shoud not be None or empty")
#     545
#     546     kwargs["output_path"] = output_path
#
# ValueError: 'output_path' shoud not be None or empty

# %%
import pandas as pd
df_cooperativas = pd.DataFrame()

# %%
# !java -version
# Out:
# java version "1.8.0_291"
# Java(TM) SE Runtime Environment (build 1.8.0_291-b10)
# Java HotSpot(TM) Client VM (build 25.291-b10, mixed mode, sharing)
